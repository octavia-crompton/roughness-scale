# %% [markdown]
# ## Roughness scaling: analysis
#
# - Loads the pre-computed slimmed summary produced by roughness_scale-load-compute.
# - All large simulation arrays (hc, vc, veg …) have been dropped.
#
# Key points this notebook:
# - The effect size increases with sigma, but not monotonically with fV

# %%
import warnings
warnings.filterwarnings("ignore")

import os
import os as _os
import sys
import shutil
import itertools as it
import contextlib
from scipy.optimize import minimize
from sklearn.preprocessing import MinMaxScaler
import statsmodels.formula.api as smf
import json
from scipy.stats import gmean
import pandas as pd

sys.path.append("/Users/octaviacrompton/Projects/roughness-scale/swof_code")


import matplotlib.cm as _cm
import matplotlib.colors as _mcolors

# %%
# ── Figure registry (src/figure_registry.py) ──────────────────────────────────
import sys as _sys
_sys.path.insert(0, "/Users/octaviacrompton/Projects/roughness-scale/src")
import figure_registry as _fig_reg

# Expose convenience names so all figure-saving cells work unchanged
_fig_dirs              = _fig_reg._fig_dirs
update_figure_registry = _fig_reg.update_figure_registry

# Note: call _fig_reg.configure(out_dir) once out_dir is set (see data-load cell)

# %%
my_modules = ['plot_SWOF', "read_SWOF", "write_SWOF", 
              "plot_config", "topo", "source_functions_1p3"]

for mod in my_modules:
    if mod in sys.modules: 
        del sys.modules[mod] 

from plot_SWOF import *
from read_SWOF import *
from plot_config import *
from topo import *
from write_SWOF import *
from source_functions_1p3 import *

# %%
project_dir = "/Users/octaviacrompton/Dropbox/FullCSWOF/Tests/"
cases = [d for d in os.listdir(project_dir) if
            ('DS_Store' not in d) and ('figures' not in d)]

# ── Storm case (used by all grid plots below) ─────────────────────────────────
_p  = 8     # rainfall intensity (cm/hr)
_tr = 60    # storm duration (min)

# %%
# out_dir must match what was used in roughness_scale-load-compute
out_dir   = os.path.join(project_dir, 'runaround_smooth')
slim_path = os.path.join(out_dir, 'summary_slim.pkl')

summary = pd.read_pickle(slim_path)
print(f'Loaded summary_slim: shape = {summary.shape}')
print('Columns:', sorted(summary.columns.tolist()))

# initialise figure registry for this session
_fig_reg.configure(out_dir, notebook_name='roughness_scale-pattern.ipynb')
# Out:
# Loaded summary_slim: shape = (1260, 342)
# Columns: ['$p t_r$', '<Sf>', '<Sf>_C_Uphp_lin', '<Sf>_C_nphp_lin', '<Sf>_T0', '<Sf>_T0_hyb', '<Sf>_T1', '<Sf>_T2', '<Sf>_Ubar2_np2', '<Sf>_cross_nU', '<Sf>_direct', '<Sf>_direct_minus_exp2', '<Sf>_direct_wet', '<Sf>_exp2', '<Sf>_hyb_Up2', '<Sf>_hyb_base', '<Sf>_hyb_cross', '<Sf>_hyb_np2', '<Sf>_hyb_num_sum', '<Sf>_hybrid_quad', '<Sf>_nbar2_Ubar2', '<Sf>_nbar2_Up2', '<Sf>_nd_T0', '<Sf>_nd_T1', '<Sf>_nd_T2', '<Sf>_nd_sumK2', '<Sf>_series2', '<U dU/dx>', '<U>', '<U>/<h>', '<U><dU/dx>', '<U>^2/<Up^2>', '<U>_CF', '<Ua>', '<Uh>', '<Up dUp/dx>', '<Up hp>', '<Up2>', '<dU/dx>', '<dh/dx>', '<dhp/dx>', '<eta ups>', '<eta2>', '<h>', '<h>_CF', '<h^2/3>', '<ha>', '<hp2>', '<n2>', '<n2><h>^-4/3', '<n>', '<n>2', '<n><U>', '<nU>', '<na>', '<np Up>', '<np hp>', '<np2>', '<q>_direct', '<q>_hform', '<q>_uform', '<r eta>', '<r ups>', '<r2>', '<ups2>', 'B_bc_NF', 'B_bc_init', 'Bbound', 'C', 'CPU_time', 'Cd', 'Cd_misc', 'Choice_dt_specific_points', 'Choice_points', 'Fr', 'IF', 'IF_err', 'IF_v', 'I_h_vol', 'I_v', 'I_v_rec', 'I_v_tr', 'I_vol', 'Kc_NF', 'Kc_init', 'Kccoef', 'Ks', 'Ks_NF', 'Ks_b', 'Ks_init', 'Ks_v', 'Kscoef', 'L', 'LB', 'LB_dist', 'LB_w', 'LB_wv', 'LV', 'LV_dist', 'L_bc_NF', 'L_bc_init', 'L_dc', 'L_dc>0', 'L_dc_dist', 'Lbound', 'N', 'Nxcell', 'Nycell', 'Psi_NF', 'Psi_init', 'Psicoef', 'R_bc_NF', 'R_bc_init', 'R_v', 'Rbound', 'Re', 'Re_90', 'Re_all', 'Re_b', 'Re_out', 'Re_v', 'So', 'T', 'T_bc_NF', 'T_bc_init', 'Tbound', 'Vol_bound_tot', 'Vol_inf_tot', 'Vol_of_tot', 'Vol_rain_tot', 'WV_avg', 'WV_dist', 'abs_err', 'alpha_WR', 'alpha_b', 'alpha_o', 'alpha_v', 'amortENO', 'aniso', 'bare_to_veg', 'beta', 'bottom_c', 'bottom_imp_discharge', 'bottom_imp_h', 'cflfix', 'curve', 'd<U>/dt', 'd_hydro', 'distance', 'divert', 'dq_h_minus_direct', 'dq_u_minus_direct', 'dt', 'dt_specific_points', 'dtfix', 'dtheta_NF', 'dtheta_init', 'dthetacoef', 'dw', 'dw_b', 'dw_v', 'dx', 'edge', 'effect', 'effect_hydro', 'effect_ratio', 'effect_ratio_Q', 'effect_ratio_Qpred2', 'effect_ratio_U', 'effect_ratio_Upred2', 'effect_ratio_geom', 'effect_ratio_hydro', 'equiv_hydro', 'equiv_hydro_IF', 'err_nd_K2', 'escape', 'escape_in_domain', 'eta', 'eta', 'eta_max', 'eta_mean', 'eta_rms', 'excess', 'excess_tr', 'fV', 'fVo', 'final_qL', 'flashy', 'flux', 'fric', 'fric_NF', 'fric_init', 'friccoef', 'h_max', 'h_min', 'h_vol', 'huv_NF', 'huv_init', 'hybrid_quad_err', 'hybrid_quad_frac_series', 'hydro', 'hydro_err', 'i_tr', 'imax_NF', 'imax_init', 'imaxcoef', 'inf', 'infl_2d', 'infl_frac', 'initialize', 'key', 'l', 'left_c', 'left_imp_discharge', 'left_imp_h', 'length', 'length_IF', 'length_source', 'lim', 'list_point_NF', 'max_length', 'modifENO', 'n_e_Q', 'n_e_Qpred2', 'n_e_U', 'n_e_Upred2', 'n_exp1', 'n_exp2', 'n_exp3', 'n_exp4', 'n_exp6', 'n_exp7', 'n_exp8', 'n_gmean', 'n_iter', 'n_misc', 'n_tr', 'name', 'nbtimes', 'nc_KC', 'nc_arith', 'nc_colebatch', 'nc_cox', 'nc_felkel', 'nc_geom', 'nc_horton', 'nc_lotter', 'nc_pavlovskii', 'nc_yen13', 'nc_yen16', 'nc_yen16alt', 'order', 'outflow_m3_c', 'outflow_vol', 'output_f', 'p', 'p-Ks_v', 'patch_LB', 'patch_LV', 'patch_WV', 'path_IF', 'path_IF_med', 'path_avg', 'path_source', 'path_source_med', 'phi_veg', 'q_max', 'r_equiv', 'r_equiv2', 'r_equiv2_hydro', 'r_equiv5', 'r_equiv5_hydro', 'r_equiv_fall', 'r_equiv_rise', 'r_ratio', 'r_std2', 'r_std5', 'rain', 'rain_NF', 'rain_vol', 'rec', 'residence', 'results', 'right_c', 'right_imp_discharge', 'right_imp_h', 'scale', 'scheme', 'scheme_type', 'seed', 'series2_err', 'sigma', 'std_x', 'suffix_o', 't', 't_comp', 't_esc', 't_f', 't_i', 't_min', 't_rain', 't_scale', 'time', 'time_to_escape', 'time_to_infiltrate', 'top_c', 'top_imp_discharge', 'top_imp_h', 'topo', 'topo_NF', 'tr', 'tracer_C', 'tracer_C_inc', 'tracer_IF', 'tracer_IF_inc', 'tracer_err', 'tracer_err_inc', 'uB', 'uB_dist', 'upslope_B', 'upslope_V', 'vcount', 'veg', 'veg_NF', 'veg_avg', 'veg_bin', 'veg_to_bare', 'veg_type', 'wet', 'x_coord', 'x_f', 'x_i', 'xc', 'y_coord', 'y_f', 'y_i', 'y_min', 'yc', 'zc', 'zcrust_NF', 'zcrust_init' ...

# %%
# ── Variable naming / display labels ──────────────────────────────────────────
# Shared labels, colour maps, and helpers live in src/labels.py
import sys as _sys
_sys.path.insert(0, "/Users/octaviacrompton/Projects/roughness-scale/src")
from labels import (
    updates, rename, renameit,
    VEG_COLORS, VEG_LABELS,
    FS_LABEL, FS_TITLE, FS_TICK, FS_LEG,
    VAR_CMAPS,
    format_name as _format_name_raw,
)

# Wrap format_name so callers don't need to pass `names` explicitly
def format_name(fld, updates=updates):
    return _format_name_raw(fld, names, updates=updates)

summary['LB_std'] = [l.std() for l in summary.LB_dist]

# ── Toggle: set USE_HYDRO = True to make 'effect_ratio' use hydrograph-based n_e
USE_HYDRO = False
if USE_HYDRO:
    summary['effect']       = summary['effect_hydro']
    summary['effect_ratio'] = summary['effect_ratio_hydro']

# %%
fig, ax = plt.subplots(1, figsize=(10, 4))

from matplotlib.lines import Line2D

_q_base = "hydro_err < 0.05 and p == 8 and tr == 60 and fV == 0.5"
_sub = summary.query(_q_base)
_sigma_vals = sorted(_sub['sigma'].unique())

if not _sigma_vals:
    print('No data matching query:', _q_base)
else:
    # Mako palette: same as used in the scatter plots
    _mako_cmap = _cm.get_cmap('mako')
    _sigma_norm = _mcolors.Normalize(vmin=0, vmax=max(_sigma_vals))
    _sigma_colors = {s: _mako_cmap(_sigma_norm(s)) for s in _sigma_vals}

for _s in _sigma_vals:
    _s_sub = _sub[_sub['sigma'] == _s]
    if not _s_sub.empty:
        plot_hydrographs(_s_sub, c=_sigma_colors[_s], ax=ax)

# Legend: one entry per sigma value
_legend_handles = [
    Line2D([0], [0], color=_sigma_colors[s], lw=2, label=fr"$\sigma={s}$")
    for s in _sigma_vals
]
ax.legend(handles=_legend_handles, title=renameit('sigma', rename),
          fontsize=FS_LEG, title_fontsize=FS_LEG,
          loc='upper left', bbox_to_anchor=(1.01, 1), borderaxespad=0)
ax.set_title(r"Hydrographs at $f_V=0.6$, $p=8$ cm/hr, $t_r=60$ min", fontsize=FS_TITLE)
ax.set_xlabel("Time (min)", fontsize=FS_LABEL)
ax.set_ylabel("Discharge (cm/hr)", fontsize=FS_LABEL)
plt.tight_layout()

# %%
fig, ax = plt.subplots(1, figsize = (10,4))

from matplotlib.lines import Line2D

subset = summary.query("hydro_err < 0.05 and p == 8 and tr == 60  and fV > 0.45 and effect_ratio < 0.65 ")
plot_hydrographs(subset, c= 'C0', ax =ax)
print ((subset.fV.max()))

subset = summary.query("hydro_err < 0.05 and p == 8 and tr == 60 and fV > 0.45 and  effect_ratio > 0.95 ")
plot_hydrographs(subset, c= 'C2', ax =ax)
print ((subset.fV.max()))

# Legend & title
ax.legend(handles=[
    Line2D([0], [0], color='C0', lw=2, label=r'$n_e/\langle n \rangle < 0.65$'),
    Line2D([0], [0], color='C2', lw=2, label=r'$n_e/\langle n \rangle > 0.95$'),
], fontsize=FS_LEG)
ax.set_title(r"Hydrographs at $f_V > 0.45$, $p=8$ cm/hr, $t_r=60$ min", fontsize=FS_TITLE)
ax.set_xlabel("Time (min)", fontsize=FS_LABEL)
ax.set_ylabel("Discharge (cm/hr)", fontsize=FS_LABEL)
# Out:
# 0.65
# 0.95
# Text(0, 0.5, 'Discharge (cm/hr)')

# %% [markdown]
# ##  Spatial pattern

# %%
if 'veg_type' in summary.columns and (summary['veg_type'] == 'blob').any():
    fig, axes = plt.subplots(1,6,figsize = (13, 3) )
    axes = axes.ravel()
    for i, key in enumerate(summary.query("L > 10 and L < 500 and sigma == 3 and aniso == 1 and veg_type == 'blob'").sort_values('fV').index[::10][:6]):
        sim = summary.loc[key]
        axes[ i].imshow(sim.veg.T[:100], cmap = "Greens")
        axes[i].imshow(sim.veg.T[:100], cmap = "Greens")

        bin_max = np.maximum(sim.LB_dist.max(), sim.L_dc_dist.max())

        axes[i].set_xticks([])
        axes[i].set_yticks([])
        axes[i].set_title("$L_v$ = {0:.1f}".format(sim.LV))

# %% [markdown]
# ## Illustrate calibration

# %%
def plot_q_compare(sim, ax):
    """Plot hydrograph comparison: avg-n discharge vs equivalent-n discharge.
    Gracefully skips series that are missing from the slimmed summary."""
    # Use .get() so missing columns don't raise AttributeError on a pandas Series row
    t       = sim.get('t')           if hasattr(sim, 'get') else getattr(sim, 't',          None)
    hydro   = sim.get('hydro')       if hasattr(sim, 'get') else getattr(sim, 'hydro',      None)
    eq_hyd  = sim.get('equiv_hydro') if hasattr(sim, 'get') else getattr(sim, 'equiv_hydro',None)
    r_avg_v   = sim.get('r_avg',   sim.get('<n>',          None)) if hasattr(sim, 'get') else None
    r_equiv_v = sim.get('r_equiv', sim.get('effect_ratio', None)) if hasattr(sim, 'get') else None

    plotted = False
    if t is not None and hydro is not None:
        lbl = r"Patchy; $\langle n \rangle$" + (r"$={:.2f}$".format(r_avg_v) if r_avg_v is not None else "")
        ax.plot(t / 60, hydro, color='#33a02c', label=lbl)
        plotted = True
    if t is not None and eq_hyd is not None:
        lbl = r"Uniform; $n_e$" + (r"$={:.2f}$".format(r_equiv_v) if r_equiv_v is not None else "")
        ax.plot(t[:len(eq_hyd)] / 60, eq_hyd, color='C1', label=lbl)
        plotted = True
    if not plotted:
        ax.text(0.5, 0.5, "hydrograph data\nnot in slim summary",
                ha='center', va='center', transform=ax.transAxes, fontsize=9, color='grey')
        ax.set_axis_off()
    else:
        ax.legend()
        ax.set_xlabel("time (min)")
        ax.set_ylabel("discharge")

# %%
query = 'hydro_err < 0.02'
from matplotlib.lines import Line2D
import matplotlib.gridspec as gridspec

sim_a = summary.query(query).query(" sigma == 5 and aniso > 1 and tr == 60  and fV > 0.3").iloc[0]
sim_b = summary.query(query).query("sigma == 5 and aniso < 0 and tr == 60 and fV > 0.3").iloc[0]

# 2-row layout: 3D panels on top row, hydrograph spanning full width below
import matplotlib.gridspec as gridspec

fig = plt.figure(figsize=(10, 8))
_gs = gridspec.GridSpec(2, 2, figure=fig, height_ratios=[1.6, 1],
                        hspace=0.05, wspace=0.05,
                        left=0.05, right=0.95, top=0.95, bottom=0.08)

ax1 = fig.add_subplot(_gs[0, 0], projection='3d')
ax2 = fig.add_subplot(_gs[0, 1], projection='3d')
ax3 = fig.add_subplot(_gs[1, :])

# ── Panel 1: 3D veg surface, contour-aligned (aniso > 0) ──────────────────────
plot_surface(
    sim_a, 'veg',
    title=r"$n_e/\langle n\rangle={:.2f},\ f_V={:.2f}$  (contour-aligned)".format(
        sim_a.effect_ratio_geom, sim_a.veg.mean()),
    color=cm.Greens,
    ax=ax1, ucut=1, dcut=0, alpha=1.0, plot_veg=False,
)

# ── Panel 2: 3D veg surface, gradient-aligned (aniso < 0) ─────────────────────
plot_surface(
    sim_b, 'veg',
    title=r"$n_e/\langle n\rangle={:.2f},\ f_V={:.2f}$  (gradient-aligned)".format(
        sim_b.effect_ratio_geom, sim_b.veg.mean()),
    color=cm.Greens,
    ax=ax2, ucut=1, dcut=0, alpha=1.0, plot_veg=False,
)

# ── Panel 3: combined hydrographs (linestyle = method, color = simulation) ────
_colors = {'contour-aligned': 'C0', 'gradient-aligned': 'C1'}

for sim, label in [(sim_a, 'contour-aligned'), (sim_b, 'gradient-aligned')]:
    t      = sim.get('t')
    hydro  = sim.get('hydro')
    eq_hyd = sim.get('equiv_hydro')
    c = _colors[label]
    if t is not None and hydro is not None:
        ax3.plot(t / 60, hydro, color=c, linestyle='-', lw=1.8)
    if t is not None and eq_hyd is not None:
        ax3.plot(t[:len(eq_hyd)] / 60, eq_hyd, color=c, linestyle='--', lw=1.8)

# Legend: colour = simulation, linestyle = quantity
_legend_handles = [
    Line2D([0], [0], color=_colors['contour-aligned'], lw=2, label='contour-aligned'),
    Line2D([0], [0], color=_colors['gradient-aligned'], lw=2, label='gradient-aligned'),
    Line2D([0], [0], color='k', lw=1.5, linestyle='-',  label=r'$\langle n\rangle$'),
    Line2D([0], [0], color='k', lw=1.5, linestyle='--', label=r'$n_e$'),
]
ax3.legend(handles=_legend_handles, frameon=False, fontsize=FS_LEG)
ax3.set_xlabel("Time (min)", fontsize=FS_LABEL)
ax3.set_ylabel("Discharge", fontsize=FS_LABEL)
ax3.tick_params(labelsize=FS_TICK)

# %%
from matplotlib.lines import Line2D as _Line2D
query = f'hydro_err < 0.05 and p == {_p} and tr == {_tr} and l == 500'

def _pick(sub_query):
    """Return first matching sim or None (with a fallback that drops `l == 500`)."""
    _r = summary.query(query).query(sub_query)
    if _r.empty:
        # fall back: drop the l == 500 constraint
        _r = summary.query(f'hydro_err < 0.05 and p == {_p} and tr == {_tr}').query(sub_query)
    return None if _r.empty else _r.iloc[0]

fig = plt.figure(figsize=(14, 9))
# 3D panels: large bounding boxes on left; hydrograph panels: smaller on right
ax0 = fig.add_axes([0.00, 0.51, 0.55, 0.50], projection='3d')   # top-left 3D
ax1 = fig.add_axes([0.58, 0.57, 0.38, 0.34])                    # top-right hydro
ax2 = fig.add_axes([0.00, 0.00, 0.55, 0.50], projection='3d')   # bot-left 3D
ax3 = fig.add_axes([0.58, 0.08, 0.38, 0.34])                    # bot-right hydro

sim = _pick("fV > 0.3 and sigma == 1 and aniso == 1")
if sim is None:
    ax0.text2D(0.5, 0.5, "no matching sim\n(sigma==1, aniso==1, fV>0.3)",
               transform=ax0.transAxes, ha='center', va='center', fontsize=12, color='grey')
else:
    plot_surface(sim, 'veg',
                 title='',
                 color=cm.Greens, ax=ax0, ucut=1, dcut=0, alpha=1.0, plot_veg=False)
    ax0.text2D(0.5, 0.9, fr"$\sigma={int(sim.sigma)}$, $f_V={sim.veg.mean():.2f}$",
               transform=ax0.transAxes, ha='center', fontsize=FS_TITLE)
    plot_q_compare(sim, ax1)
    _h, _l = ax1.get_legend_handles_labels()
    if _h:
        _h.append(_Line2D([0], [0], color='none'))
        _l.append(fr"$n_e/\langle n \rangle = {sim.effect_ratio:.2f}$")
        ax1.legend(handles=_h, labels=_l)
    print(sim['<U>']**2, sim['<Up2>'], sim['<U>']**2/sim['<Up2>'])

sim = _pick("fV > 0.3 and sigma == 5 and aniso == 1")
if sim is None:
    ax2.text2D(0.5, 0.5, "no matching sim\n(sigma==5, aniso==1, fV>0.3)",
               transform=ax2.transAxes, ha='center', va='center', fontsize=12, color='grey')
else:
    plot_surface(sim, 'veg',
                 title='',
                 color=cm.Greens, ax=ax2, ucut=1, dcut=0, alpha=1.0, plot_veg=False)
    ax2.text2D(0.5, 0.9, fr"$\sigma={int(sim.sigma)}$, $f_V={sim.veg.mean():.2f}$",
               transform=ax2.transAxes, ha='center', fontsize=FS_TITLE)
    plot_q_compare(sim, ax3)
    _h, _l = ax3.get_legend_handles_labels()
    if _h:
        _h.append(_Line2D([0], [0], color='none'))
        _l.append(fr"$n_e/\langle n \rangle = {sim.effect_ratio:.2f}$")
        ax3.legend(handles=_h, labels=_l)
    print(sim['<U>']**2, sim['<Up2>'], sim['<U>']**2/sim['<Up2>'])
# Out:
# 0.006392149803351 0.0018726717741906307 3.4133850317222243
# 0.00699183347126111 0.0019091773307012441 3.662223177923969

# %%
_band_mask = summary['veg_type'].str.contains('band')
summary.loc[_band_mask, 'aniso'] = 1
summary.loc[_band_mask, 'stripe_count'] = summary.loc[_band_mask, 'l'] / summary.loc[_band_mask, 'sigma']
summary['effect_ratio_exp3'] = summary['n_exp3'] / summary['<n>']

_blob_mask = summary['veg_type'] == 'blob'
summary.loc[_blob_mask, 'stripe_count'] = summary.loc[_blob_mask, 'aniso']

# %%
# ── Parameters ────────────────────────────────────────────────────────────────
fV      = 0.6   # centre of fV window
fV_half = 0.05  # half-width → selects fV in [fV - fV_half, fV + fV_half]
hue_var = None  # None = auto: 'aniso' if only blobs, else 'veg_type'


def _build_hue_info(df, hue_var):
    """Return (plot_hue_col, palette, label_order, hue_label) for the given hue variable."""
    _veg_types = df['veg_type'].unique()
    if hue_var is None:
        hue_var = 'aniso' if set(_veg_types) == {'blob'} else 'veg_type'

    if hue_var == 'veg_type':
        palette = {k: v for k, v in VEG_COLORS.items() if k in _veg_types}
        _fallback = iter(_cm.tab10.colors)
        for vt in _veg_types:
            if vt not in palette:
                palette[vt] = next(_fallback)
        return hue_var, palette, None, 'veg type'

    if hue_var == 'aniso':
        _aniso_name = {v: ('gradient-aligned' if v < 0 else
                           'isotropic'        if v == 1 else
                           'contour-aligned') for v in sorted(df['aniso'].unique())}
        df['_aniso_label'] = df['aniso'].map(_aniso_name)
        _label_order = [l for l in ['gradient-aligned', 'isotropic', 'contour-aligned']
                        if l in df['_aniso_label'].unique()]
        _aniso_vals = sorted(_aniso_name.keys())
        _bg_cmap = _mcolors.LinearSegmentedColormap.from_list(
            'blue_green', ['#2166ac', '#92c5de', '#a6d96a', '#1a9641'])
        _norm = _mcolors.Normalize(vmin=min(_aniso_vals), vmax=max(_aniso_vals))
        palette = {_aniso_name[v]: _bg_cmap(_norm(v)) for v in _aniso_vals}
        return '_aniso_label', palette, _label_order, 'Orientation'

    return hue_var, 'viridis', None, hue_var


def _dedup_legend(handles, labels):
    """Return handles/labels with duplicate labels removed (keep first)."""
    seen, out_h, out_l = set(), [], []
    for h, l in zip(handles, labels):
        if l not in seen:
            seen.add(l); out_h.append(h); out_l.append(l)
    return out_h, out_l


# ── Filter + hue setup ────────────────────────────────────────────────────────
_df = summary[(summary['fV'] >= fV - fV_half) & (summary['fV'] <= fV + fV_half)].copy()

if _df.empty:
    print(f"No data in fV window [{fV - fV_half}, {fV + fV_half}]. "
          f"Available fV: {sorted(summary['fV'].unique())}")
else:
    _is_band    = _df['veg_type'].str.contains('band').any()
    _plot_hue, _palette, _label_order, _hue_label = _build_hue_info(_df, hue_var)

    _marker_pool = ['^', 'o', 's', 'D', 'P', 'X', 'v', '<', '>']
    _hue_vals    = list(_palette.keys()) if isinstance(_palette, dict) else sorted(_df[_plot_hue].unique())
    _markers     = {v: _marker_pool[i % len(_marker_pool)] for i, v in enumerate(_hue_vals)}

# %%
# ── Plot: effect_ratio vs LV (patch scale), faceted by (p, tr) ────────────────────────
if not _df.empty:
    from matplotlib.lines import Line2D

    _df_plot = _df.copy()

    p_vals  = sorted(_df_plot['p'].unique())
    tr_vals = sorted(_df_plot['tr'].unique())
    nrows, ncols = len(p_vals), len(tr_vals)

    fig, axes = plt.subplots(nrows, ncols, figsize=(4 * ncols, 3 * nrows),
                             sharex=True, sharey=True)
    axes = np.array(axes).reshape(nrows, ncols)

    for ri, p in enumerate(p_vals):
        for ci, tr in enumerate(tr_vals):
            ax  = axes[ri, ci]
            sub = _df_plot[(_df_plot['p'] == p) & (_df_plot['tr'] == tr)]
            if sub.empty:
                ax.set_visible(False)
                continue

            sns.scatterplot(
                data=sub,
                x='LV', y='effect_ratio',
                hue=_plot_hue,
                style=_plot_hue,
                markers=_markers,
                palette=_palette,
                ax=ax,
                legend=False,
            )

            ax.set_title(f"$p={p}$ cm/hr, $t_r={tr}$ min", fontsize=FS_TITLE)
            ax.set_xlabel(renameit('LV', rename) if ri == nrows - 1 else "",
                          fontsize=FS_LABEL)
            ax.set_ylabel(renameit('effect_ratio', rename) if ci == 0 else "", fontsize=FS_LABEL)
            ax.tick_params(labelsize=FS_TICK)

    # Figure-level legend
    _legend_values = _label_order if (_plot_hue == '_aniso_label' and _label_order is not None) else _hue_vals
    _legend_handles = []
    for v in _legend_values:
        _color = _palette[v] if isinstance(_palette, dict) else 'gray'
        _label = VEG_LABELS.get(v, v) if _plot_hue == 'veg_type' else v
        _legend_handles.append(
            Line2D([0], [0], marker=_markers[v], linestyle='None',
                   markerfacecolor=_color, markeredgecolor='k', markeredgewidth=0.5,
                   markersize=7, label=_label)
        )

    fig.legend(
        handles=_legend_handles,
        loc='center left',
        bbox_to_anchor=(1.02, 0.5),
        title=_hue_label,
        frameon=True,
        fontsize=FS_LEG,
        title_fontsize=FS_LEG,
    )

    fig.suptitle(
        fr"$n_e/\langle n \rangle$ vs $L_V$  ($f_V = {fV:.2f}$)",
        fontsize=FS_TITLE,
    )
    plt.tight_layout()
    plt.subplots_adjust(right=0.82)

# %%
# ── Plot: effect_ratio vs LB (bare-soil patch length), faceted by (p, tr) ────────────────────────
if not _df.empty:
    from matplotlib.lines import Line2D

    _df_plot = _df.copy()

    p_vals  = sorted(_df_plot['p'].unique())
    tr_vals = sorted(_df_plot['tr'].unique())
    nrows, ncols = len(p_vals), len(tr_vals)

    fig, axes = plt.subplots(nrows, ncols, figsize=(4 * ncols, 3 * nrows),
                             sharex=True, sharey=True)
    axes = np.array(axes).reshape(nrows, ncols)

    for ri, p in enumerate(p_vals):
        for ci, tr in enumerate(tr_vals):
            ax  = axes[ri, ci]
            sub = _df_plot[(_df_plot['p'] == p) & (_df_plot['tr'] == tr)]
            if sub.empty:
                ax.set_visible(False)
                continue

            sns.scatterplot(
                data=sub,
                x='LB', y='effect_ratio',
                hue=_plot_hue,
                style=_plot_hue,
                markers=_markers,
                palette=_palette,
                ax=ax,
                legend=False,
            )

            ax.set_title(f"$p={p}$ cm/hr, $t_r={tr}$ min", fontsize=FS_TITLE)
            ax.set_xlabel(renameit('LB', rename) if ri == nrows - 1 else "",
                          fontsize=FS_LABEL)
            ax.set_ylabel(renameit('effect_ratio', rename) if ci == 0 else "", fontsize=FS_LABEL)
            ax.tick_params(labelsize=FS_TICK)

    # Figure-level legend
    _legend_values = _label_order if (_plot_hue == '_aniso_label' and _label_order is not None) else _hue_vals
    _legend_handles = []
    for v in _legend_values:
        _color = _palette[v] if isinstance(_palette, dict) else 'gray'
        _label = VEG_LABELS.get(v, v) if _plot_hue == 'veg_type' else v
        _legend_handles.append(
            Line2D([0], [0], marker=_markers[v], linestyle='None',
                   markerfacecolor=_color, markeredgecolor='k', markeredgewidth=0.5,
                   markersize=7, label=_label)
        )

    fig.legend(
        handles=_legend_handles,
        loc='center left',
        bbox_to_anchor=(1.02, 0.5),
        title=_hue_label,
        frameon=True,
        fontsize=FS_LEG,
        title_fontsize=FS_LEG,
    )

    fig.suptitle(
        fr"$n_e/\langle n \rangle$ vs $L_B$  ($f_V = {fV:.2f}$)",
        fontsize=FS_TITLE,
    )
    plt.tight_layout()
    plt.subplots_adjust(right=0.82)

# %%
# sigma vs effect_ratio — one panel per fV value, 2 rows × 4 cols
# (storm case set at top of notebook: _p, _tr)
from matplotlib.lines import Line2D

_ncols = 4
_df = summary.query(f"hydro_err < 0.05 and tr == {_tr} and p == {_p}").copy()
_fv_vals = sorted(_df['fV'].unique())
_nrows = max(1, -(-len(_fv_vals) // _ncols))
# Ensure at least 2 rows so the 8th panel exists
if _nrows * _ncols < len(_fv_vals) + 1:
    _nrows = max(2, _nrows)

# ── Anisotropy labels + palette + markers ────────────────────────────────────
_aniso_name = {v: ('gradient-aligned' if v < 0 else
                   'isotropic'        if v == 1 else
                   'contour-aligned') for v in sorted(_df['aniso'].unique())}
_df['_aniso_label'] = _df['aniso'].map(_aniso_name)
_label_order = [l for l in ['gradient-aligned', 'isotropic', 'contour-aligned']
                if l in _df['_aniso_label'].unique()]
_bg_cmap = _mcolors.LinearSegmentedColormap.from_list(
    'blue_green', ['#2166ac', '#92c5de', '#a6d96a', '#1a9641'])
_aniso_vals = sorted(_aniso_name.keys())
_norm = _mcolors.Normalize(vmin=min(_aniso_vals), vmax=max(_aniso_vals))
_aniso_palette = {_aniso_name[v]: _bg_cmap(_norm(v)) for v in _aniso_vals}
_aniso_markers = {lbl: mk for lbl, mk in
                  zip(['gradient-aligned', 'isotropic', 'contour-aligned'], ['^', 'o', 's'])
                  if lbl in _label_order}

# horizontal offset per orientation category to separate overlapping points
_df['sigma'] = _df['sigma'].astype(float)
_orient_offsets = {
    'gradient-aligned': -0.15,
    'isotropic':          0.0,
    'contour-aligned':   +0.15,
}
for _lbl, _off in _orient_offsets.items():
    _df.loc[_df['_aniso_label'] == _lbl, 'sigma'] += _off

# ── fV discrete colour palette (viridis) ─────────────────────────────────────
_fv_cmap = plt.get_cmap('viridis')
_fv_norm = _mcolors.Normalize(vmin=min(_fv_vals), vmax=max(_fv_vals))
_fv_colors = {fv: _fv_cmap(_fv_norm(fv)) for fv in _fv_vals}

fig, axes = plt.subplots(_nrows, _ncols, figsize=(16, 3.5 * _nrows),
                         sharey=True, sharex=True)
axes_flat = np.array(axes).flatten()

for i, fv in enumerate(_fv_vals):
    ax = axes_flat[i]
    _sub = _df[_df['fV'] == fv]
    sns.scatterplot(_sub, x='sigma', y='effect_ratio', ax=ax,
                    hue='_aniso_label', hue_order=_label_order,
                    style='_aniso_label', style_order=_label_order,
                    markers=_aniso_markers,
                    palette=_aniso_palette, s=40, legend=False)
    ax.set_title(f"$f_V$ = {fv:.2g}", fontsize=FS_TITLE)
    ax.set_xlabel(renameit('sigma') if i >= _ncols else '', fontsize=FS_LABEL)
    ax.tick_params(labelsize=FS_TICK)

# ── 8th panel: summary scatter, all fV ───────────────────────────────────────
_summary_idx = len(_fv_vals)
if _summary_idx < len(axes_flat):
    ax_sum = axes_flat[_summary_idx]
    ax_sum.scatter(
        _df['sigma'], _df['effect_ratio'],
        c=[_fv_colors[fv] for fv in _df['fV']],
        s=25, alpha=0.7, edgecolors='none',
    )
    ax_sum.set_title('all $f_V$', fontsize=FS_TITLE)
    ax_sum.set_xlabel(renameit('sigma'), fontsize=FS_LABEL)
    ax_sum.tick_params(labelsize=FS_TICK)

    _fv_handles = [
        Line2D([0], [0], marker='o', linestyle='None',
               markerfacecolor=_fv_colors[fv], markeredgecolor='none',
               markersize=6, label=f'{fv:.2g}')
        for fv in _fv_vals
    ]
    ax_sum.legend(handles=_fv_handles, title=renameit('fV', rename),
                  fontsize=FS_LEG - 1, title_fontsize=FS_LEG - 1, ncol=1,
                  bbox_to_anchor=(1.02, 0.8), loc='center left', frameon=True)

    _next_unused = _summary_idx + 1
else:
    _next_unused = _summary_idx

# y-labels on left column only
_axes2d = np.array(axes).reshape(_nrows, _ncols)
for ri in range(_nrows):
    _axes2d[ri, 0].set_ylabel(renameit('effect_ratio'), fontsize=FS_LABEL)
    for ci in range(1, _ncols):
        _axes2d[ri, ci].set_ylabel('')

# Hide any remaining unused axes
for ax in axes_flat[_next_unused:]:
    ax.set_visible(False)

# ── Orientation legend ────────────────────────────────────────────────────────
_leg_handles = [
    Line2D([0], [0], marker=_aniso_markers[lbl], linestyle='None',
           markerfacecolor=_aniso_palette[lbl], markeredgecolor='k',
           markeredgewidth=0.4, markersize=7, label=lbl)
    for lbl in _label_order if lbl in _aniso_markers
]
_axes2d[0, 3].legend(handles=_leg_handles, title='Orientation',
                     fontsize=FS_LEG, title_fontsize=FS_LEG,
                     bbox_to_anchor=(1.02, 0.8), loc='center left', frameon=True)

plt.suptitle(f"$t_r$ = {int(_tr)} min,  $p$ = {_p} cm/hr", y=1.02, fontsize=FS_TITLE)
plt.tight_layout()
plt.show()

# %%
# sigma vs effect_ratio — one panel per fV value, 2 rows × 3 cols
# (storm case set at top of notebook: _p, _tr)
from matplotlib.lines import Line2D

_nrows, _ncols = 2, 3
_df = summary.query(f"hydro_err < 0.05 and tr == {_tr} and p == {_p}").copy()

# Drop fV = 0.05 and take the 6 remaining values
_fv_vals = [fv for fv in sorted(_df['fV'].unique()) if fv != 0.05]

# ── Anisotropy labels + palette + markers ────────────────────────────────
_aniso_name = {v: ('gradient-aligned' if v < 0 else
                   'isotropic'        if v == 1 else
                   'contour-aligned') for v in sorted(_df['aniso'].unique())}
_df['_aniso_label'] = _df['aniso'].map(_aniso_name)
_label_order = [l for l in ['gradient-aligned', 'isotropic', 'contour-aligned']
                if l in _df['_aniso_label'].unique()]
_bg_cmap = _mcolors.LinearSegmentedColormap.from_list(
    'blue_green', ['#2166ac', '#92c5de', '#a6d96a', '#1a9641'])
_aniso_vals = sorted(_aniso_name.keys())
_norm = _mcolors.Normalize(vmin=min(_aniso_vals), vmax=max(_aniso_vals))
_aniso_palette = {_aniso_name[v]: _bg_cmap(_norm(v)) for v in _aniso_vals}
_aniso_markers = {lbl: mk for lbl, mk in
                  zip(['gradient-aligned', 'isotropic', 'contour-aligned'], ['^', 'o', 's'])
                  if lbl in _label_order}

# horizontal offset per orientation category to separate overlapping points
_df['sigma'] = _df['sigma'].astype(float)
_orient_offsets = {
    'gradient-aligned': -0.15,
    'isotropic':          0.0,
    'contour-aligned':   +0.15,
}
for _lbl, _off in _orient_offsets.items():
    _df.loc[_df['_aniso_label'] == _lbl, 'sigma'] += _off

fig, axes = plt.subplots(_nrows, _ncols, figsize=(12, 7),
                         sharey=True, sharex=True)
axes_flat = np.array(axes).flatten()

for i, fv in enumerate(_fv_vals):
    ax = axes_flat[i]
    _sub = _df[_df['fV'] == fv]
    sns.scatterplot(_sub, x='sigma', y='effect_ratio', ax=ax,
                    hue='_aniso_label', hue_order=_label_order,
                    style='_aniso_label', style_order=_label_order,
                    markers=_aniso_markers,
                    palette=_aniso_palette, s=40, legend=False)
    ax.set_title(f"$f_V$ = {fv:.2g}", fontsize=FS_TITLE)
    ax.set_xlabel(renameit('sigma', rename) if i >= _ncols else '', fontsize=FS_LABEL)
    ax.tick_params(labelsize=FS_TICK)

# y-labels on left column only
_axes2d = np.array(axes).reshape(_nrows, _ncols)
for ri in range(_nrows):
    _axes2d[ri, 0].set_ylabel(renameit('effect_ratio', rename), fontsize=FS_LABEL)
    for ci in range(1, _ncols):
        _axes2d[ri, ci].set_ylabel('')

# hide any extra axes
for ax in axes_flat[len(_fv_vals):]:
    ax.set_visible(False)

# ── Orientation legend — right of figure ─────────────────────────────────
_leg_handles = [
    Line2D([0], [0], marker=_aniso_markers[lbl], linestyle='None',
           markerfacecolor=_aniso_palette[lbl], markeredgecolor='k',
           markeredgewidth=0.4, markersize=7, label=lbl)
    for lbl in _label_order if lbl in _aniso_markers
]
fig.legend(handles=_leg_handles, title='Orientation',
           fontsize=FS_LEG, title_fontsize=FS_LEG,
           loc='center left', bbox_to_anchor=(0.85, 0.5), frameon=True)

plt.suptitle(f"$n_e/\\langle n \\rangle$ vs $\\sigma$   ($t_r$ = {int(_tr)} min,  $p$ = {_p} cm/hr)",
             fontsize=FS_TITLE)
plt.tight_layout()
plt.subplots_adjust(right=0.82)
plt.show()

# %%
# LV vs effect_ratio — one panel per fV value, 2 rows × 3 cols
# (storm case set at top of notebook: _p, _tr)
from matplotlib.lines import Line2D

_nrows, _ncols = 2, 3
_df = summary.query(f"hydro_err < 0.05 and tr == {_tr} and p == {_p}").copy()

# Drop fV = 0.05 and take the 6 remaining values
_fv_vals = [fv for fv in sorted(_df['fV'].unique()) if fv != 0.05]

# ── Anisotropy labels + palette + markers ────────────────────────────────
_aniso_name = {v: ('gradient-aligned' if v < 0 else
                   'isotropic'        if v == 1 else
                   'contour-aligned') for v in sorted(_df['aniso'].unique())}
_df['_aniso_label'] = _df['aniso'].map(_aniso_name)
_label_order = [l for l in ['gradient-aligned', 'isotropic', 'contour-aligned']
                if l in _df['_aniso_label'].unique()]
_bg_cmap = _mcolors.LinearSegmentedColormap.from_list(
    'blue_green', ['#2166ac', '#92c5de', '#a6d96a', '#1a9641'])
_aniso_vals = sorted(_aniso_name.keys())
_norm = _mcolors.Normalize(vmin=min(_aniso_vals), vmax=max(_aniso_vals))
_aniso_palette = {_aniso_name[v]: _bg_cmap(_norm(v)) for v in _aniso_vals}
_aniso_markers = {lbl: mk for lbl, mk in
                  zip(['gradient-aligned', 'isotropic', 'contour-aligned'], ['^', 'o', 's'])
                  if lbl in _label_order}

# horizontal offset per orientation category to separate overlapping points
_df['LV'] = _df['LV'].astype(float)
_orient_offsets = {
    'gradient-aligned': -0.15,
    'isotropic':          0.0,
    'contour-aligned':   +0.15,
}
for _lbl, _off in _orient_offsets.items():
    _df.loc[_df['_aniso_label'] == _lbl, 'LV'] += _off

fig, axes = plt.subplots(_nrows, _ncols, figsize=(12, 7),
                         sharey=True, sharex='row')
axes_flat = np.array(axes).flatten()

for i, fv in enumerate(_fv_vals):
    ax = axes_flat[i]
    _sub = _df[_df['fV'] == fv]
    sns.scatterplot(_sub, x='LV', y='effect_ratio', ax=ax,
                    hue='_aniso_label', hue_order=_label_order,
                    style='_aniso_label', style_order=_label_order,
                    markers=_aniso_markers,
                    palette=_aniso_palette, s=40, legend=False)
    ax.set_title(f"$f_V$ = {fv:.2g}", fontsize=FS_TITLE)
    ax.set_xlabel('$L_V$' if i >= _ncols else '', fontsize=FS_LABEL)
    ax.tick_params(labelsize=FS_TICK)

# y-labels on left column only
_axes2d = np.array(axes).reshape(_nrows, _ncols)
for ri in range(_nrows):
    _axes2d[ri, 0].set_ylabel(renameit('effect_ratio', rename), fontsize=FS_LABEL)
    for ci in range(1, _ncols):
        _axes2d[ri, ci].set_ylabel('')

# hide any extra axes
for ax in axes_flat[len(_fv_vals):]:
    ax.set_visible(False)

# ── Orientation legend — right of figure ─────────────────────────────────
_leg_handles = [
    Line2D([0], [0], marker=_aniso_markers[lbl], linestyle='None',
           markerfacecolor=_aniso_palette[lbl], markeredgecolor='k',
           markeredgewidth=0.4, markersize=7, label=lbl)
    for lbl in _label_order if lbl in _aniso_markers
]
fig.legend(handles=_leg_handles, title='Orientation',
           fontsize=FS_LEG, title_fontsize=FS_LEG,
           loc='center left', bbox_to_anchor=(0.85, 0.8), frameon=True)

# plt.suptitle(f"$n_e/\\langle n \\rangle$ vs $L_V$ ",
#              fontsize=FS_TITLE)
plt.tight_layout()
plt.subplots_adjust(right=0.82)

# ── Save fig3 ────────────────────────────────────────────────────────────
_fig_dir, _, _ = _fig_dirs()
_name = 'fig3_effect_ratio_vs_LV.png'
fig.savefig(_os.path.join(_fig_dir, _name), dpi=300, bbox_inches='tight')
update_figure_registry(
    'fig3', _name,
    description=(
        '2×3 panel figure showing $n_e/\\langle n\\rangle$ vs patch lengthscale $L_V$ '
        'for six vegetation fractions ($f_V = 0.1$ to $0.9$, excluding 0.05), '
        'at a single storm ($p$, $t_r$). Points coloured and shaped by orientation '
        '(gradient-aligned, isotropic, contour-aligned) with small horizontal offsets '
        'for legibility. Shows that $n_e/\\langle n\\rangle$ generally increases with $L_V$, '
        'approaching unity for the largest patches, and that the orientation effect '
        'is strongest at intermediate $f_V$.'
    ),
    concise=(
        'Effect ratio vs patch lengthscale $L_V$, panelled by $f_V$, coloured by orientation. '
        'Ratio increases with patch size toward unity; orientation sensitivity peaks near $f_V \\approx 0.5$.'
    ),
)
plt.show()
# Out:
# Registry updated → ../figures/runaround_smooth/figure_registry.txt  [fig3]

# %%
# LB vs effect_ratio — one panel per fV value, 2 rows × 3 cols
# (storm case set at top of notebook: _p, _tr)
from matplotlib.lines import Line2D

_nrows, _ncols = 2, 3
_df = summary.query(f"hydro_err < 0.05 and tr == {_tr} and p == {_p}").copy()

# Drop fV = 0.05 and take the 6 remaining values
_fv_vals = [fv for fv in sorted(_df['fV'].unique()) if fv != 0.05]

# ── Anisotropy labels + palette + markers ────────────────────────────────
_aniso_name = {v: ('gradient-aligned' if v < 0 else
                   'isotropic'        if v == 1 else
                   'contour-aligned') for v in sorted(_df['aniso'].unique())}
_df['_aniso_label'] = _df['aniso'].map(_aniso_name)
_label_order = [l for l in ['gradient-aligned', 'isotropic', 'contour-aligned']
                if l in _df['_aniso_label'].unique()]
_bg_cmap = _mcolors.LinearSegmentedColormap.from_list(
    'blue_green', ['#2166ac', '#92c5de', '#a6d96a', '#1a9641'])
_aniso_vals = sorted(_aniso_name.keys())
_norm = _mcolors.Normalize(vmin=min(_aniso_vals), vmax=max(_aniso_vals))
_aniso_palette = {_aniso_name[v]: _bg_cmap(_norm(v)) for v in _aniso_vals}
_aniso_markers = {lbl: mk for lbl, mk in
                  zip(['gradient-aligned', 'isotropic', 'contour-aligned'], ['^', 'o', 's'])
                  if lbl in _label_order}

# horizontal offset per orientation category to separate overlapping points
_df['LB'] = _df['LB'].astype(float)
_orient_offsets = {
    'gradient-aligned': -0.15,
    'isotropic':          0.0,
    'contour-aligned':   +0.15,
}
for _lbl, _off in _orient_offsets.items():
    _df.loc[_df['_aniso_label'] == _lbl, 'LB'] += _off

fig, axes = plt.subplots(_nrows, _ncols, figsize=(12, 7),
                         sharey=True, sharex=True)
axes_flat = np.array(axes).flatten()

for i, fv in enumerate(_fv_vals):
    ax = axes_flat[i]
    _sub = _df[_df['fV'] == fv]
    sns.scatterplot(_sub, x='LB', y='effect_ratio', ax=ax,
                    hue='_aniso_label', hue_order=_label_order,
                    style='_aniso_label', style_order=_label_order,
                    markers=_aniso_markers,
                    palette=_aniso_palette, s=40, legend=False)
    ax.set_title(f"$f_V$ = {fv:.2g}", fontsize=FS_TITLE)
    ax.set_xlabel(renameit('LB', rename) if i >= _ncols else '', fontsize=FS_LABEL)
    ax.tick_params(labelsize=FS_TICK)

# y-labels on left column only
_axes2d = np.array(axes).reshape(_nrows, _ncols)
for ri in range(_nrows):
    _axes2d[ri, 0].set_ylabel(renameit('effect_ratio', rename), fontsize=FS_LABEL)
    for ci in range(1, _ncols):
        _axes2d[ri, ci].set_ylabel('')

# hide any extra axes
for ax in axes_flat[len(_fv_vals):]:
    ax.set_visible(False)

# ── Orientation legend — right of figure ─────────────────────────────────
_leg_handles = [
    Line2D([0], [0], marker=_aniso_markers[lbl], linestyle='None',
           markerfacecolor=_aniso_palette[lbl], markeredgecolor='k',
           markeredgewidth=0.4, markersize=7, label=lbl)
    for lbl in _label_order if lbl in _aniso_markers
]
fig.legend(handles=_leg_handles, title='Orientation',
           fontsize=FS_LEG, title_fontsize=FS_LEG,
           loc='center left', bbox_to_anchor=(0.82, 0.8), frameon=True)

plt.suptitle(f"$n_e/\\langle n \\rangle$ vs $L_B$   ($t_r$ = {int(_tr)} min,  $p$ = {_p} cm/hr)",
             fontsize=FS_TITLE)
plt.tight_layout()
plt.subplots_adjust(right=0.82)

# ── Save to scratch (not in manuscript) ──────────────────────────────────
_, _scratch, _ = _fig_dirs()
fig.savefig(_os.path.join(_scratch, 'effect_ratio_vs_LB_by_fV.png'), dpi=200, bbox_inches='tight')
plt.show()

# %%
# ── LV vs LB: explanatory power for effect_ratio ────────────────────────────
# Compares R² of simple OLS  effect_ratio ~ X  across all (fV, p, tr) groups
# and overall, after partialling out fV (within-group R²).

from scipy.stats import pearsonr
import statsmodels.api as _sm

_cmp = summary.query("hydro_err < 0.05")[['effect_ratio', 'LV', 'LB', 'fV', 'p', 'tr']].dropna()

def _r2_ols(x, y):
    """R² of OLS y ~ x (with intercept)."""
    _X = _sm.add_constant(x)
    return _sm.OLS(y, _X).fit().rsquared

# ── 1. Overall R² ────────────────────────────────────────────────────────────
r2_LV_overall = _r2_ols(_cmp['LV'], _cmp['effect_ratio'])
r2_LB_overall = _r2_ols(_cmp['LB'], _cmp['effect_ratio'])
print(f"Overall R²   LV = {r2_LV_overall:.3f}   LB = {r2_LB_overall:.3f}")

# ── 2. Within-fV R² (pool residuals after removing fV group means) ───────────
_cmp = _cmp.copy()
for _col in ['effect_ratio', 'LV', 'LB']:
    _cmp[f'{_col}_dm'] = _cmp[_col] - _cmp.groupby('fV')[_col].transform('mean')

r2_LV_within = _r2_ols(_cmp['LV_dm'], _cmp['effect_ratio_dm'])
r2_LB_within = _r2_ols(_cmp['LB_dm'], _cmp['effect_ratio_dm'])
print(f"Within-fV R² LV = {r2_LV_within:.3f}   LB = {r2_LB_within:.3f}")

# ── 3. Per-storm-case R² ─────────────────────────────────────────────────────
print(f"\n{'p':>5} {'tr':>5}  {'R²(LV)':>8}  {'R²(LB)':>8}  {'winner':>8}")
for (_p_val, _tr_val), _grp in _cmp.groupby(['p', 'tr']):
    if len(_grp) < 5:
        continue
    _rv = _r2_ols(_grp['LV'], _grp['effect_ratio'])
    _rb = _r2_ols(_grp['LB'], _grp['effect_ratio'])
    _w = 'LV' if _rv > _rb else 'LB'
    print(f"{_p_val:>5} {int(_tr_val):>5}  {_rv:>8.3f}  {_rb:>8.3f}  {_w:>8}")
# Out:
# Overall R²   LV = 0.320   LB = 0.152
# Within-fV R² LV = 0.419   LB = 0.195
#
#     p    tr    R²(LV)    R²(LB)    winner
#     5    30     0.272     0.170        LV
#     5    60     0.339     0.150        LV
#     8    30     0.318     0.159        LV
#     8    60     0.353     0.135        LV

# %%
# ══════════════════════════════════════════════════════════════════════════════
# Figure 2 — Effect ratio: dependence on vegetation fraction, patch length
#             scale, and storm intensity
# ══════════════════════════════════════════════════════════════════════════════
from matplotlib.lines import Line2D
import matplotlib.gridspec as gridspec

_fig2_df = summary.query("hydro_err < 0.05 and aniso > 1").copy()
_fig2_df['_d'] = _fig2_df['p'].astype(float) * _fig2_df['tr'].astype(float) / 60

# ── Storm pairs: least and most intense ──────────────────────────────────────
_combos = _fig2_df.groupby(['p', 'tr'])['_d'].first().reset_index()
_combos['_d'] = _combos['_d'].astype(float)
_lo = _combos.loc[_combos['_d'].idxmin(), ['p', 'tr']]
_hi = _combos.loc[_combos['_d'].idxmax(), ['p', 'tr']]
_storm_pairs = [(_lo['p'], _lo['tr']), (_hi['p'], _hi['tr'])]

# ── Sigma colour scale (mako) ────────────────────────────────────────────────
_sigma_levels = sorted(_fig2_df['sigma'].unique())
_mako = _cm.get_cmap('mako')
_sigma_norm = _mcolors.Normalize(vmin=0, vmax=max(_sigma_levels + [5.5]))  # add small buffer to avoid max value being too dark
_sigma_palette = {s: _mako(_sigma_norm(s)) for s in _sigma_levels}

# ── sigma → median vegetation patch lengthscale (L_V) ───────────────────────
_sigma_to_LV = summary.groupby('sigma')['LV'].median().to_dict()

# ── 2×2 layout ───────────────────────────────────────────────────────────────
#   Top row:    effect_ratio vs fV (least intense | most intense)
#   Bottom row: hydrographs at fV≈0.5 coloured by sigma (same two storms)
fig, axes = plt.subplots(2, 2, figsize=(12, 8), sharey='row')

# ── Small fV offset per sigma for visual separation (top row only) ───────────
_fig2_scatter = _fig2_df.copy()
_sigma_offset = {s: i * 0.015 for i, s in enumerate(_sigma_levels)}
for s in _sigma_levels:
    _fig2_scatter.loc[_fig2_scatter['sigma'] == s, 'fV'] += _sigma_offset[s]

for ci, (p, tr) in enumerate(_storm_pairs):
    # ── Top row: scatter n_e/⟨n⟩ vs fV ──────────────────────────────────────
    ax_top = axes[0, ci]
    _sub_top = _fig2_scatter[(_fig2_scatter['p'] == p) & (_fig2_scatter['tr'] == tr)]

    sns.scatterplot(
        data=_sub_top, x='fV', y='effect_ratio', ax=ax_top,
        hue='sigma', hue_order=_sigma_levels,
        palette=_sigma_palette, s=40, alpha=0.8,
        legend=False,
    )

    ax_top.axhline(1.0, color='grey', ls='--', lw=0.7, zorder=0)
    _intensity = 'least intense' if ci == 0 else 'most intense'
    _d_val = p * tr / 60
    ax_top.set_title(
        f"$p={p}$ cm/hr, $t_r={int(tr)}$ min  ({_intensity})",
        fontsize=FS_TITLE,
    )
    ax_top.set_xlabel(renameit('fV', rename), fontsize=FS_LABEL)
    ax_top.set_ylabel(
        renameit('effect_ratio', rename) if ci == 0 else '',
        fontsize=FS_LABEL,
    )
    ax_top.tick_params(labelsize=FS_TICK)

    # ── Bottom row: hydrographs at fV ≈ 0.5, coloured by sigma ──────────────
    ax_bot = axes[1, ci]
    _sub_hydro = _fig2_df[
        (_fig2_df['p'] == p) & (_fig2_df['tr'] == tr)
        & (_fig2_df['fV'] >= 0.45) & (_fig2_df['fV'] <= 0.55)
    ]

    for _s in _sigma_levels:
        _s_sub = _sub_hydro[_sub_hydro['sigma'] == _s]
        if not _s_sub.empty:
            plot_hydrographs(_s_sub, c=_sigma_palette[_s], ax=ax_bot, alpha=0.5)

    ax_bot.set_title(
        f"Hydrographs at $f_V \\approx 0.5$  ({_intensity})",
        fontsize=FS_TITLE,
    )
    ax_bot.set_xlabel("Time (min)", fontsize=FS_LABEL)
    ax_bot.set_ylabel("Discharge (cm/hr)" if ci == 0 else '', fontsize=FS_LABEL)
    ax_bot.tick_params(labelsize=FS_TICK)

# ── Shared legend (right side) ───────────────────────────────────────────────
def _lv_label(s):
    if s in _sigma_to_LV:
        return f'{_sigma_to_LV[s]:.0f} m'
    return fr"$\sigma={s}$"

_legend_handles = [
    Line2D([0], [0], marker='o', linestyle='None',
           markerfacecolor=_sigma_palette[s], markeredgecolor='k',
           markeredgewidth=0.4, markersize=7, label=_lv_label(s))
    for s in _sigma_levels
]
fig.legend(
    handles=_legend_handles,
    title=r'$L_V$ (patch scale)',
    fontsize=FS_LEG, title_fontsize=FS_LEG,
    loc='center right',
    bbox_to_anchor=(1.0, 0.8),
    borderaxespad=0,
    frameon=True,
)

plt.tight_layout()
plt.subplots_adjust(right=0.88)
plt.show()


# ── Save figure 2 ────────────────────────────────────────────────────────────
_fig_dir, _, _ = _fig_dirs()
_name = 'fig2_effect_ratio_fV_2x2.png'
fig.savefig(_os.path.join(_fig_dir, _name), dpi=300, bbox_inches='tight')
update_figure_registry(
    'fig2', _name,
    description=(
        r"2×2 panel figure. Top row: $n_e/\langle n\rangle$ vs vegetation "
        r"fraction $f_V$ for (left) least intense and (right) most intense storm, "
        r"coloured by patch lengthscale $L_V$ (mako palette). Dashed line at "
        r"unity. Small horizontal offsets per $L_V$ level aid legibility. "
        r"Bottom row: outlet hydrographs at $f_V\approx 0.5$ for the same two "
        r"storms, coloured by $L_V$. Shows that $n_e/\langle n\rangle < 1$ for "
        r"all cases, with the minimum near $f_V\approx 0.5$; ratio increases "
        r"toward unity with larger patch scale; modest storm sensitivity."
    ),
    concise=(
        r"Main results figure: $n_e/\langle n\rangle$ vs $f_V$ for least and "
        r"most intense storms (top row) with corresponding hydrographs at "
        r"$f_V\approx 0.5$ (bottom row), both coloured by patch lengthscale "
        r"$L_V$. Demonstrates that the ratio is always below unity, is "
        r"minimised near $f_V=0.5$, and increases with patch size."
    ),
)
# Out:
# Registry updated → ../figures/runaround_smooth/figure_registry.txt  [fig2]

# %%
# --- filter and make a working copy
query = "hydro_err < 0.05 and tr == 60 and p == 8"
subset = summary.query(query).copy()

# --- your deliberate shifts (since `tr == 60` is already in the query,
#     these apply to the whole subset)
subset["l"]     = subset["l"] + 10
subset["sigma"] = subset["sigma"].astype(int) 

# --- round σ to two decimals and force ordered categorical for clean ticks
subset["sigma"] = subset["sigma"].astype(float).round(2)
sigma_order = np.sort(subset["sigma"].dropna().unique())
subset["sigma"] = pd.Categorical(subset["sigma"], categories=sigma_order, ordered=True)

# --- rename columns for pretty axis labels (keeps numeric values intact)
subset = subset.rename(columns=rename)

xfld = renameit("sigma")          # r"$\sigma$"
yfld = renameit("effebct_ratio")   # r"$n_e/\langle n \rangle$"
cfld = renameit("aniso")          # "anisotropic"

# %%
np.linspace(0.05, 0.95, 8),
# Out:
# (array([0.05      , 0.17857143, 0.30714286, 0.43571429, 0.56428571,
#         0.69285714, 0.82142857, 0.95      ]),)

# %% [markdown]
# ## Sensitivity to storm characteristics

# %%
summary['d'] = summary['p'] * summary['tr'] / 60
ax = sns.scatterplot(summary.query("fV == 0.5 and aniso == 1 "),
                     x='d', y='effect_ratio', hue='p', palette='coolwarm')
ax.set_xlabel(r"storm depth $d$ (cm)", fontsize=12)
ax.set_ylabel(rename.get('effect_ratio', r'$n_e/\langle n \rangle$'), fontsize=12)
ax.legend(title=r"$p$ (cm/hr)", fontsize=11, title_fontsize=11)
# sns.scatterplot(summary.query("fV == 0.6 and aniso == 1 and sigma ==5 "), x='p', y='effect_ratio')

_, _scratch, _ = _fig_dirs()
ax.get_figure().savefig(_os.path.join(_scratch, 'storm_depth_vs_effect_ratio.png'),
                        dpi=200, bbox_inches='tight')

# %% [markdown]
# ## Illustrate vegetation patterns

# %%
# 3D vegetation surface — side by side: σ=2 vs σ>4 vs uniform

fig = plt.figure(figsize=(12, 5))

# Right subplot: uniform roughness — real topography, single light-green colour
ax3 = fig.add_subplot(131, projection='3d')
sim3 = summary.iloc[0]
_light_green_cmap = _mcolors.LinearSegmentedColormap.from_list(
    'light_green', ['#a1d99b', '#a1d99b'])  # constant light green
plot_surface(
    sim3, 'veg',
    title='Uniform roughness',
    color=_light_green_cmap,
    ax=ax3,
    ucut=1,
    dcut=0,
    alpha=1.0,
    plot_veg=False
)



# Left subplot: sigma = 2
ax1 = fig.add_subplot(132, projection='3d')
sim1 = summary.query(" fV > 0.2 and fV < 0.5 and sigma == 1 and aniso > 1").iloc[0]
plot_surface(
    sim1, 'veg',
    title=r'Vegetation surface, $\sigma=2$ (no tracers)',
    color=cm.Greens,
    ax=ax1,
    ucut=1,
    dcut=0,
    alpha=1.0,
    plot_veg=False
)

# Middle subplot: sigma > 4
ax2 = fig.add_subplot(133, projection='3d')
sim2 = summary.query(" fV > 0.2 and fV < 0.5 and sigma > 4 and aniso > 1").iloc[0]
plot_surface(
    sim2, 'veg',
    title=r'Vegetation surface, $\sigma>4$ (no tracers)',
    color=cm.Greens,
    ax=ax2,
    ucut=1,
    dcut=0,
    alpha=1.0,
    plot_veg=False
)

plt.tight_layout()
plt.show()

# %%
# 3D vegetation surface — side by side: σ=2 vs σ>4 vs uniform

fig = plt.figure(figsize=(12, 5))

# Right subplot: uniform roughness — real topography, single light-green colour
ax1 = fig.add_subplot(131, projection='3d')
sim1 = summary.query(" fV > 0.2 and fV < 0.5 and sigma == 5 and aniso < 1").iloc[0]
plot_surface(
    sim1, 'veg',
    title=r'Contour-aligned vegetation, $\sigma=5$',
    color=cm.Greens,
    ax=ax1,
    ucut=1,
    dcut=0,
    alpha=1.0,
    plot_veg=False
)


# Left subplot: sigma = 2
ax1 = fig.add_subplot(132, projection='3d')
sim1 = summary.query(" fV > 0.2 and fV < 0.5 and sigma == 5  and aniso == 1").iloc[0]
plot_surface(
    sim1, 'veg',
    title=r'Isotropic vegetation, $\sigma=5$',
    color=cm.Greens,
    ax=ax1,
    ucut=1,
    dcut=0,
    alpha=1.0,
    plot_veg=False
)

# Middle subplot: sigma > 4
ax2 = fig.add_subplot(133, projection='3d')
sim2 = summary.query(" fV > 0.2 and fV < 0.5 and sigma == 5 and aniso > 1").iloc[0]
plot_surface(
    sim2, 'veg',
    title=r'Contour-aligned vegetation, $\sigma=5$',
    color=cm.Greens,
    ax=ax2,
    ucut=1,
    dcut=0,
    alpha=1.0,
    plot_veg=False
)

plt.tight_layout()
plt.show()

# %%
# Stacked hillslopes with varying green shades (dark → light)

_n_layers = 6
_z_spacing = 0.5  # vertical offset between layers

# Green shades from dark to light
_greens = ['#1a6b1a', '#2d8e2d', '#4aad4a', '#74c474', '#a1d99b', '#c7e9c0']

fig = plt.figure(figsize=(6, 6))
ax3 = fig.add_subplot(111, projection='3d')
ax3 = fix_3D_axes(ax3)

sim3 = summary.iloc[0]
_xc, _yc, _zc, _ = trim(sim3, sim3.veg, dcut=0, ucut=1)



ax3.view_init(20, 20)

for _i, _shade in enumerate(_greens):
    _z_offset = _i * _z_spacing
    _scale = 1.2 - _i * 0.0

    # Anchor scaling to one edge (e.g. the upslope/ridge edge)
    _xc_anchor = _xc.max()   # or .max() depending on slope orientation
    _yc_anchor = _yc.max()

    _xc_scaled = _xc_anchor + (_xc - _xc_anchor) * _scale
    _yc_scaled = _yc_anchor + (_yc - _yc_anchor) * _scale

    _cmap_i = _mcolors.LinearSegmentedColormap.from_list(
        f'green_{_i}', [_shade, _shade])
    _colors_i = _cmap_i(np.ones_like(_zc) * 0.5)
    ax3.plot_surface(
        _xc_scaled, _yc_scaled, _zc + _z_offset,
        facecolors=_colors_i, rstride=1, cstride=1,
        linewidth=0, antialiased=True, shade=False, alpha=0.8
    )

# %%
def plot_surface(sim, fld, title = '', color = cm.Greens,
                plot_veg = False, erode = False, vmin = None, vmax = None,
                 ax = '', dcut = 0, ucut = 0, stack = 0, alpha = 0.5,
                 color_scale =1.2):
    '''
    color_scale: when vmax is not provided, the data max is multiplied by this
    factor before normalising, pushing values into the lighter part of the
    colormap.  Increase to lighten further (e.g. 3.0); set to 1.0 for original
    behaviour.
    '''
    if ax == '':
        fig = plt.figure(figsize=(5,5))
        ax = fig.add_subplot(111, projection='3d')

    ax = fix_3D_axes(ax)
    norm = plt.Normalize()
    xc, yc, zc, veg = trim(sim, sim.veg, dcut, ucut, stack )
    xc, yc, zc, Ic = trim(sim, sim[fld], dcut, ucut, stack )

    if vmin == None:
        vmin = Ic.min()
    if vmax == None:
        vmax = Ic.max() * color_scale

    I_norm = colors.Normalize( vmin = vmin,
                             vmax =  vmax
                            )
    I_colors = color(I_norm(Ic))
    
    if dcut == 0:
        veg = np.array(sim['veg']).reshape( sim.Nxcell, sim.Nycell)[:, ucut:]
    else:
        veg = np.array(sim['veg']).reshape( sim.Nxcell, sim.Nycell)[:, ucut:-dcut]
        
    veg_norm = colors.Normalize(vmin =  0. ,
                                vmax =  1.2
                              )
    if erode == True:
        veg = veg - cv2.erode(veg, np.ones((3,3)), 1)
    veg_colors = cm.Greens(veg_norm(veg ))

    ax.xaxis.set_pane_color((1.0, 1.0, 1.0, 1.0))

    if plot_veg:
        
        ax.plot_surface(xc, yc , zc ,
                        facecolors = veg_colors, 
                        rstride=1, cstride=1,
                        linewidth=0, antialiased=True, shade=False, alpha=1)

    ax.plot_surface(xc, yc , zc ,
                    facecolors=I_colors, rstride=1, cstride=1,
                    linewidth=0, antialiased=True, shade=False, alpha=alpha)   
  
    ax.view_init(25, 20)

    t = ax.set_title(title, fontsize  = 14)
    t.set_y(0.9)
    
    return  ax

# %%
# 3D vegetation surface only — side by side: σ=2 vs σ>4 vs uniform

# Illustrate library of vegetation surfaces by plotting the same topography multiple times with varying green shades, simulating a "stacked hillslope" effect. For each spatially varying roughness case, an 'equivalent' uniform roughness case is determined through calibration.

fig = plt.figure(figsize=(10, 7))

# Right subplot: uniform roughness — real topography, single light-green colour
ax3 = fig.add_subplot(131, projection='3d')
sim3 = summary.iloc[0]
_xc, _yc, _zc, _ = trim(sim3, sim3.veg, dcut=0, ucut=1)

_n_layers = 5
_z_spacing = 0.5  # vertical offset between layers

# Green shades from dark to light
_greens = ['#1a6b1a', '#2d8e2d', '#4aad4a', '#74c474', '#a1d99b', '#c7e9c0']
_greens = ['#1a6b1a', '#2d8e2d', '#4aad4a', '#a1d99b', '#c7e9c0']


for _i, _shade in enumerate(_greens):
    _z_offset = _i * _z_spacing
    _scale = 1.2 - _i * 0.02

    # Anchor scaling to one edge (e.g. the upslope/ridge edge)
    _xc_anchor = _xc.max()   # or .max() depending on slope orientation
    _yc_anchor = _yc.max()

    _xc_scaled = _xc_anchor + (_xc - _xc_anchor) * _scale
    _yc_scaled = _yc_anchor + (_yc - _yc_anchor) * _scale

    _cmap_i = _mcolors.LinearSegmentedColormap.from_list(
        f'green_{_i}', [_shade, _shade])
    _colors_i = _cmap_i(np.ones_like(_zc) * 0.5)
    ax3.plot_surface(
        _xc_scaled, _yc_scaled, _zc + _z_offset,
        facecolors=_colors_i, rstride=1, cstride=1,
        linewidth=0, edgecolor='none', antialiased=True, shade=False, alpha=0.8
    )

ax3 = fix_3D_axes(ax3)
ax3.view_init(25, 20)
ax3.set_title('Uniform roughness', fontsize=14)

# Left subplot: sigma = 2
ax1 = fig.add_subplot(132, projection='3d')
sim1 = summary.query(" fV > 0.2 and fV < 0.5 and sigma == 1 and aniso > 1").iloc[0]
plot_surface(
    sim1, 'veg',
    title=r'Vegetation surface, $\sigma=2$',
    color=cm.Greens,
    ax=ax1,
    ucut=1,
    dcut=0,
    alpha=1.0,
    plot_veg=False
)
print (ax1.get_zlim())
ax1.set_zlim([ax1.get_zlim()[0], ax1.get_zlim()[1]*1.6])


# Middle subplot: sigma > 4
ax2 = fig.add_subplot(133, projection='3d')
sim2 = summary.query(" fV > 0.2 and fV < 0.5 and sigma > 4 and aniso > 1").iloc[0]
plot_surface(
    sim2, 'veg',
    title=r'Vegetation surface, $\sigma>4$ ',
    color=cm.Greens,
    ax=ax2,
    ucut=1,
    dcut=0,
    alpha=1.0,
    plot_veg=False
)
ax2.set_zlim([ax2.get_zlim()[0], ax2.get_zlim()[1]*1.6])

plt.tight_layout()
plt.show()
# Out:
# (np.float64(-0.04124579124579125), np.float64(2.021043771043771))

# %% [markdown]
# ## Bad figures

# %%
fig, axes = plt.subplots(1, 3, figsize = (14,4), sharey = True)

yfld = "effect_ratio"
xfld  = 'fV'
sfld = "sigma"
cfld = 'sigma'
summary['fV'] = summary['fV'].astype(float).round(2)
summary['sigma'] = summary['sigma'].astype(int)

query ='hydro_err < 0.1 and aniso < 0'
g = sns.boxplot(data = summary.query(query).rename(rename, axis = 1), 
                    x = rename[xfld], y = rename[yfld],  
                   hue = rename[cfld],  ax = axes[0],
                    palette = mako(len(summary.query(query)[cfld].unique()))
                   )
g.legend().set_visible(False)


query ='hydro_err < 0.1 and aniso == 1'
g = sns.boxplot(data = summary.query(query).rename(rename, axis = 1), 
                    x = rename[xfld], y = rename[yfld],  
                   hue = rename[cfld],  ax = axes[1],
                    palette = mako(len(summary.query(query)[cfld].unique())))
g.legend().set_visible(False)

query ='hydro_err < 0.1 and aniso >= 1'
g = sns.boxplot(data = summary.query(query).rename(rename, axis = 1), 
                    x = rename[xfld], y = rename[yfld],  
                   hue = rename[cfld],  ax = axes[2],
                    palette = mako(len(summary.query(query)[cfld].unique())))
g.legend(loc='center left',  bbox_to_anchor=(1.0, 0.5), ncol=1 , title = rename[cfld])    

axes[0].axhline(0.5, c = 'gray')
axes[1].axhline(0.5, c = 'gray')
axes[2].axhline(0.5, c = 'gray')
axes[0].set_title("Along-slope bands")
axes[1].set_title("Isotropic")
axes[2].set_title("Cross-slope bands")
# Out:
# Text(0.5, 1.0, 'Cross-slope bands')
